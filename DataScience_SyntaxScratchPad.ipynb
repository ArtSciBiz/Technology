# %%
import pandas as pd
weatherStations = pd.read_csv("weather-stations20140101-20141231.csv")
weatherStations.head()
# Out:
#                  Stn_Name     Lat     Long Prov   Tm  DwTm    D    Tx  DwTx  \
# 0               CHEMAINUS  48.935 -123.742   BC  8.2   0.0  NaN  13.5   0.0
# 1  COWICHAN LAKE FORESTRY  48.824 -124.133   BC  7.0   0.0  3.0  15.0   0.0
# 2           LAKE COWICHAN  48.829 -124.052   BC  6.8  13.0  2.8  16.0   9.0
# 3        DISCOVERY ISLAND  48.425 -123.226   BC  NaN   NaN  NaN  12.5   0.0
# 4     DUNCAN KELVIN CREEK  48.735 -123.728   BC  7.7   2.0  3.4  14.5   2.0
#
#     Tn  ...  DwP    P%N  S_G    Pd  BS  DwBS  BS%    HDD  CDD   Stn_No
# 0  1.0  ...  0.0    NaN  0.0  12.0 NaN   NaN  NaN  273.3  0.0  1011500
# 1 -3.0  ...  0.0  104.0  0.0  12.0 NaN   NaN  NaN  307.0  0.0  1012040
# 2 -2.5  ...  9.0    NaN  NaN  11.0 NaN   NaN  NaN  168.1  0.0  1012055
# 3  NaN  ...  NaN    NaN  NaN   NaN NaN   NaN  NaN    NaN  NaN  1012475
# 4 -1.0  ...  2.0    NaN  NaN  11.0 NaN   NaN  NaN  267.7  0.0  1012573
#
# [5 rows x 25 columns]

# %%
#Print the contents of the directory
import os
with os.scandir("./data/samples") as directoryContents:
    for content in directoryContents:
        print(content.name)
# Out:
# iris
# weather
# airline
# olympic-medals
# osb

# %%
import os
with os.scandir("./data/samples/iris") as directoryContents:
    for content in directoryContents:
        print(content.name)
# Out:
# iris.csv

# %%
# Scanning or walking down a directory tree and printing the names of the directories and files
import os
for dirpath, dirnames, files in os.walk('./data'):
    print(f'Found directory: {dirpath}')
    for file_name in files:
        print(file_name)
# Out:
# Found directory: ./data
# Found directory: ./data/samples
# Found directory: ./data/samples/iris
# iris.csv
# Found directory: ./data/samples/weather
# weather-stations20140101-20141231.csv
# Found directory: ./data/samples/airline
# 2008.csv.bz2
# Found directory: ./data/samples/olympic-medals
# medals.csv
# Found directory: ./data/samples/osb
# board.csv
# license.txt
# school.csv

# %%
import pandas
weatherStationsDataFrame = pandas.read_csv('weather-stations20140101-20141231.csv')
weatherStationsDataFrame.tail()
# Out:
#           Stn_Name     Lat    Long Prov    Tm  DwTm    D    Tx  DwTx    Tn  \
# 1336        NAIN A  56.550 -61.683   NL -22.6   0.0 -5.2  -6.8   0.0 -33.5
# 1337        NAIN A  56.551 -61.682   NL -19.2  24.0  NaN  -7.5  17.0   NaN
# 1338        SAGLEK  58.333 -62.586   NL -24.4   2.0  NaN -13.5   1.0 -32.3
# 1339  TUKIALIK BAY  54.716 -58.358   NL -22.8   2.0  NaN  -5.8   1.0 -32.5
# 1340      WABUSH A  52.923 -66.865   NL -27.7   0.0  NaN -13.6   0.0 -46.8
#
#       ...   DwP   P%N   S_G   Pd  BS  DwBS  BS%     HDD  CDD   Stn_No
# 1336  ...   0.0  66.0  74.0  5.0 NaN   NaN  NaN  1136.5  0.0  8502800
# 1337  ...  17.0   NaN   NaN  4.0 NaN   NaN  NaN   148.7  0.0  8502801
# 1338  ...   NaN   NaN   NaN  NaN NaN   NaN  NaN  1101.2  0.0  8503249
# 1339  ...   NaN   NaN   NaN  NaN NaN   NaN  NaN  1060.0  0.0  8503992
# 1340  ...   0.0   NaN   NaN  2.0 NaN   NaN  NaN  1279.9  0.0  8504177
#
# [5 rows x 25 columns]

# %%
# Scanning or walking down a directory tree and printing the names of the directories and files
import os
for dirpath, dirnames, files in os.walk('./data'):
    print(f'Found directory: {dirpath}')
    for file_name in files:
        print(file_name)
# Out:
# Found directory: ./data
# Found directory: ./data/samples
# Found directory: ./data/samples/iris
# iris.csv
# Found directory: ./data/samples/weather
# weather-stations20140101-20141231.csv
# Found directory: ./data/samples/airline
# 2008.csv.bz2
# Found directory: ./data/samples/olympic-medals
# medals.csv
# Found directory: ./data/samples/osb
# board.csv
# license.txt
# school.csv

# %%
# Scanning or walking down a directory tree and printing the names of the directories and files
import os
for dirpath, dirnames, files in os.walk('./data'):
    print(f'Found directory: {dirpath}')
    for file_name in files:
        print(file_name)
# Out:
# Found directory: ./data
# Found directory: ./data/samples
# Found directory: ./data/samples/iris
# iris.csv
# Found directory: ./data/samples/weather
# weather-stations20140101-20141231.csv
# Found directory: ./data/samples/airline
# 2008.csv.bz2
# Found directory: ./data/samples/olympic-medals
# medals.csv
# Found directory: ./data/samples/osb
# board.csv
# license.txt
# school.csv

# %%
#Utilize Pandas library to instantiate DataFrame
import pandas
weatherStationsDataFrame = pandas.read_csv('https://raw.githubusercontent.com/Jazzwall/bigdataucourse/master/weather-stations20140101-20141231.csv')

# %%
#Print the column headings in the data frame
weatherStationsDataFrame.columns
# Out:
# Index(['Stn_Name', 'Lat', 'Long', 'Prov', 'Tm', 'DwTm', 'D', 'Tx', 'DwTx',
#        'Tn', 'DwTn', 'S', 'DwS', 'S%N', 'P', 'DwP', 'P%N', 'S_G', 'Pd', 'BS',
#        'DwBS', 'BS%', 'HDD', 'CDD', 'Stn_No'],
#       dtype='object')

# %%
#Print the data types in the data frame
weatherStationsDataFrame.dtypes
# Out:
# Stn_Name     object
# Lat         float64
# Long        float64
# Prov         object
# Tm          float64
# DwTm        float64
# D           float64
# Tx          float64
# DwTx        float64
# Tn          float64
# DwTn        float64
# S           float64
# DwS         float64
# S%N         float64
# P           float64
# DwP         float64
# P%N         float64
# S_G         float64
# Pd          float64
# BS          float64
# DwBS        float64
# BS%         float64
# HDD         float64
# CDD         float64
# Stn_No       object
# dtype: object

# %%
#Print Unique Station Names (turn our attention to Stn_Name) 
weatherStationsDataFrame.Stn_Name.unique()
# Out:
# array(['CHEMAINUS', 'COWICHAN LAKE FORESTRY', 'LAKE COWICHAN', ...,
#        'SAGLEK', 'TUKIALIK BAY', 'WABUSH A'], dtype=object)

# %%
#Print top ten values in the data frame
weatherStationsDataFrame.head(10)
# Out:
#                  Stn_Name     Lat     Long Prov   Tm  DwTm    D    Tx  DwTx  \
# 0               CHEMAINUS  48.935 -123.742   BC  8.2   0.0  NaN  13.5   0.0
# 1  COWICHAN LAKE FORESTRY  48.824 -124.133   BC  7.0   0.0  3.0  15.0   0.0
# 2           LAKE COWICHAN  48.829 -124.052   BC  6.8  13.0  2.8  16.0   9.0
# 3        DISCOVERY ISLAND  48.425 -123.226   BC  NaN   NaN  NaN  12.5   0.0
# 4     DUNCAN KELVIN CREEK  48.735 -123.728   BC  7.7   2.0  3.4  14.5   2.0
# 5       ESQUIMALT HARBOUR  48.432 -123.439   BC  8.8   0.0  NaN  13.1   0.0
# 6           GALIANO NORTH  48.985 -123.573   BC  8.9   7.0  NaN  13.5   7.0
# 7                 MALAHAT  48.575 -123.530   BC  7.2   1.0  NaN  12.7   1.0
# 8               METCHOSIN  48.374 -123.561   BC  NaN   NaN  NaN   NaN   NaN
# 9          NORTH COWICHAN  48.824 -123.718   BC  NaN   NaN  NaN   NaN   NaN
#
#     Tn  ...   DwP    P%N  S_G    Pd  BS  DwBS  BS%    HDD  CDD   Stn_No
# ...

# %%
import time 
import sys
import types
import pandas as pd
import numpy as np 
# Point to the CSV file that resides in an cloud object storage(COR) bucket that is made publicly accessible on the Web (data is public)
csvFile_gdpData = 'https://datasciencepythonbasicsproject-donotdelete-pr-raugcxqfl1o6nv.s3.us.cloud-object-storage.appdomain.cloud/BureauOfEconomicAnalysis_GDP_Annual.csv'

# Read CSV file using pandas read_csv method, & retrieve gross domestic product data from the file 
df_gdpData = pd.read_csv(csvFile_gdpData)
df_gdpData.head()
# Out:
#    YEAR  GDP_BILLIONS
# 0  1929         104.6
# 1  1930          92.2
# 2  1931          77.4
# 3  1932          59.5
# 4  1933          57.2

# %%
links={'GDP':'https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/PY0101EN/projects/coursera_project/clean_gdp.csv',\
       'unemployment':'https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/PY0101EN/projects/coursera_project/clean_unemployment.csv'}

csvFile_gdpData = links['GDP']
df_gdpData = pd.read_csv(csvFile_gdpData)
df_gdpData.head()
# Out:
#    date  level-current  level-chained  change-current  change-chained
# 0  1948          274.8         2020.0            -0.7            -0.6
# 1  1949          272.8         2008.9            10.0             8.7
# 2  1950          300.2         2184.0            15.7             8.0
# 3  1951          347.3         2360.0             5.9             4.1
# 4  1952          367.7         2456.1             6.0             4.7

# %%
import pandas as pd
import matplotlib.pyplot as plt

filename = "https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DA0101EN/auto.csv"

headers = ["symboling","normalized-losses","make","fuel-type","aspiration", "num-of-doors","body-style",
         "drive-wheels","engine-location","wheel-base", "length","width","height","curb-weight","engine-type",
         "num-of-cylinders", "engine-size","fuel-system","bore","stroke","compression-ratio","horsepower",
         "peak-rpm","city-mpg","highway-mpg","price"]

# Assign headers to the data frame & read the data trame
df = pd.read_csv(filename, names=headers)

df.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %%
# Summarize statistics using describe method of pandas applied to the dataframe of pandas (similar to descriptive statistics in MS Excel)
df.describe()
# Out:
#         symboling  wheel-base      length       width      height  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000
# mean     0.834146   98.756585  174.049268   65.907805   53.724878
# std      1.245307    6.021776   12.337289    2.145204    2.443522
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.300000   64.100000   52.000000
# 50%      1.000000   97.000000  173.200000   65.500000   54.100000
# 75%      2.000000  102.400000  183.100000   66.900000   55.500000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#        curb-weight  engine-size  compression-ratio    city-mpg  highway-mpg
# count   205.000000   205.000000         205.000000  205.000000   205.000000
# mean   2555.565854   126.907317          10.142537   25.219512    30.751220
# std     520.680204    41.642693           3.972040    6.542142     6.886443
# ...

# %%
#Print all the column names in the DataFrame
print("Printing column names in the DataFrame \n--------------------------------------")
for columnName in df:
    print(columnName)
# Out:
# Printing column names in the DataFrame
# --------------------------------------
# symboling
# normalized-losses
# make
# fuel-type
# aspiration
# num-of-doors
# body-style
# drive-wheels
# engine-location
# wheel-base
# length
# width
# height
# curb-weight
# engine-type
# num-of-cylinders
# engine-size
# fuel-system
# bore
# stroke
# compression-ratio
# horsepower
# peak-rpm
# city-mpg
# highway-mpg
# price

# %%
# Make of the car is a categorical variable. So, let's list all the various types of makes
print("Car Makers:\n-------------\n",df["make"].value_counts())
# Out:
# Car Makers:
# -------------
#  toyota           32
# nissan           18
# mazda            17
# mitsubishi       13
# honda            13
# volkswagen       12
# subaru           12
# peugot           11
# volvo            11
# dodge             9
# bmw               8
# mercedes-benz     8
# audi              7
# plymouth          7
# saab              6
# porsche           5
# isuzu             4
# chevrolet         3
# alfa-romero       3
# jaguar            3
# renault           2
# mercury           1
# Name: make, dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt

filename = "https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DA0101EN/auto.csv"

headers = ["symboling","normalized-losses","make","fuel-type","aspiration", "num-of-doors","body-style",
         "drive-wheels","engine-location","wheel-base", "length","width","height","curb-weight","engine-type",
         "num-of-cylinders", "engine-size","fuel-system","bore","stroke","compression-ratio","horsepower",
         "peak-rpm","city-mpg","highway-mpg","price"]

# Assign headers to the data frame & read the data trame
df = pd.read_csv(filename, names=headers)

df.head()

#Predictor Variable (independent variable) (X-axis) - Engine Size
#Target Variable (dependent variable) (Y-axis) - Price of the car

y=df["engine-size"]
x=df["price"]

plt.scatter(x,y);
plt.title("Scatterplot of Engine Size vs Price")
plt.xlabel("Engine Size")
plt.ylabel("Price")
# Out:
# Text(0, 0.5, 'Price')

# %%
df1=pd.DataFrame({'A':["a","b","a","c","a","c","b"]})
df1['A'].value_counts()
# Out:
# a    3
# b    2
# c    2
# Name: A, dtype: int64

# %%
df_grp = df.groupby(['make', 'price']).mean()
df_grp
# Out:
#                    symboling  wheel-base  length  width  height  curb-weight  \
# make        price
# alfa-romero 13495        3.0       88.60   168.8   64.1    48.8       2548.0
#             16500        2.0       91.55   170.0   64.8    50.6       2685.5
# audi        13950        2.0       99.80   176.6   66.2    54.3       2337.0
#             15250        2.0       99.80   177.3   66.3    53.1       2507.0
#             17450        2.0       99.40   176.6   66.4    54.3       2824.0
#             17710        1.0      105.80   192.7   71.4    55.7       2844.0
#             18920        1.0      105.80   192.7   71.4    55.7       2954.0
#             23875        1.0      105.80   192.7   71.4    55.9       3086.0
#             ?            0.0       99.50   178.2   67.9    52.0       3053.0
# bmw         16430        2.0      101.20   176.8   64.8    54.3       2395.0
#             16925        0.0      101.20   176.8   64.8    54.3       2395.0
# ...

# %%
#df_grp = df.groupby(['make', 'price']).mean()
#df_grp

df.head()
df_grpx = df[['body-style', 'drive-wheels']]
df_grpx.head()

#df_pivot = df_grpx.pivot(index='drive-wheels', columns='body-style')
# Out:
#     body-style drive-wheels
# 0  convertible          rwd
# 1  convertible          rwd
# 2    hatchback          rwd
# 3        sedan          fwd
# 4        sedan          4wd

# %%
import matplotlib.pyplot as plt
import seaborn as sns

df.head()

#sns.regplot(x="engine-size", y="price", data=df)
#plt.ylim(0,)
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %%
# !!! FIX THIS !!!
df_anova=df[["make", "price"]]
grouped_anova=df_anova.groupby(["make"])
grouped_anova

# %%
df.shape
# Out:
# (205, 26)

# %%
# !!! STARTING A NEW DATAFRAME !!! NEW FILE. 

import pandas as pd
import numpy as np
path='https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DA0101EN/automobileEDA.csv'
df = pd.read_csv(path)
df.head()
# Out:
#    symboling  normalized-losses         make aspiration num-of-doors  \
# 0          3                122  alfa-romero        std          two
# 1          3                122  alfa-romero        std          two
# 2          1                122  alfa-romero        std          two
# 3          2                164         audi        std         four
# 4          2                164         audi        std         four
#
#     body-style drive-wheels engine-location  wheel-base    length  ...  \
# 0  convertible          rwd           front        88.6  0.811148  ...
# 1  convertible          rwd           front        88.6  0.811148  ...
# 2    hatchback          rwd           front        94.5  0.822681  ...
# 3        sedan          fwd           front        99.8  0.848630  ...
# 4        sedan          4wd           front        99.4  0.848630  ...
#
#    compression-ratio  horsepower  peak-rpm city-mpg highway-mpg    price  \
# ...

# %%
# %%capture
# !pip install seaborn

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
print(df.dtypes)
# Out:
# symboling              int64
# normalized-losses      int64
# make                  object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower           float64
# peak-rpm             float64
# city-mpg               int64
# highway-mpg            int64
# price                float64
# city-L/100km         float64
# horsepower-binned     object
# diesel                 int64
# gas                    int64
# dtype: object

# %%
df.corr()
# Out:
#                    symboling  normalized-losses  wheel-base    length  \
# symboling           1.000000           0.466264   -0.535987 -0.365404
# normalized-losses   0.466264           1.000000   -0.056661  0.019424
# wheel-base         -0.535987          -0.056661    1.000000  0.876024
# length             -0.365404           0.019424    0.876024  1.000000
# width              -0.242423           0.086802    0.814507  0.857170
# height             -0.550160          -0.373737    0.590742  0.492063
# curb-weight        -0.233118           0.099404    0.782097  0.880665
# engine-size        -0.110581           0.112360    0.572027  0.685025
# bore               -0.140019          -0.029862    0.493244  0.608971
# stroke             -0.008245           0.055563    0.158502  0.124139
# compression-ratio  -0.182196          -0.114713    0.250313  0.159733
# horsepower          0.075819           0.217299    0.371147  0.579821
# ...

# %%
df[['bore', 'stroke', 'compression-ratio', 'horsepower']].corr()
# Out:
#                        bore    stroke  compression-ratio  horsepower
# bore               1.000000 -0.055390           0.001263    0.566936
# stroke            -0.055390  1.000000           0.187923    0.098462
# compression-ratio  0.001263  0.187923           1.000000   -0.214514
# horsepower         0.566936  0.098462          -0.214514    1.000000

# %%
# Engine size as potential predictor variable of price
sns.regplot(x="engine-size", y="price", data=df)
plt.ylim(0,)
# Out:
# (0, 56102.73542627737)

# %%
from sklearn.linear_model import LinearRegression 

lm=LinearRegression()
X = df[['highway-mpg']]
Y = df['price']
reg = lm.fit(X, Y)
Yhat = lm.predict(X)

c = lm.intercept_
m = lm.coef_

print("y intercept = ", c)
print("m the slope = ", m)

carPrices = m*df["highway-mpg"] + c

carPrices.head()
# Out:
# y intercept =  38423.305858157386
# m the slope =  [-821.73337832]
# 0    16236.504643
# 1    16236.504643
# 2    17058.238022
# 3    13771.304508
# 4    20345.171535
# Name: highway-mpg, dtype: float64

# %%
df.head()
Z = df[['horsepower', 'curb-weight', 'engine-size', 'highway-mpg']]
reg = lm.fit(Z, df['price'])
Yhat = lm.predict(Z)

# %%
import seaborn as sns
sns.regplot(x="highway-mpg", y="price", data=df)
plt.ylim(0,)
# Out:
# (0, 48281.8341775678)

# %%
import seaborn as sns
sns.residplot(df['highway-mpg'], df['price'])

# %%
#distribution plot a powerful visualization to see how predicted curve aligns with acutal curve during the model training
import seaborn as sns

#ax1 = sns.distplot(df['price'], color="r", label="Actual Value")
ax1 = sns.distplot(df['price'], hist=False, color="r", label="Actual Value")
sns.distplot(Yhat, hist=False, color="b", label="Fitted Values", ax=ax1)

# %%
import numpy as np

y = df[["price"]]
x = df[["highway-mpg"]]
#f=np.polyfit(x,y,3)
#p=np.poly1d(f)

pr=PolynomialFeatures(degree=2)
pr.fit_transform([1,2], include_bias=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-207-5c3359ff8c96> in <module>
#       6 #p=np.poly1d(f)
#       7
# ----> 8 pr=PolynomialFeatures(degree=2)
#       9 pr.fit_transform([1,2], include_bias=False)
#
# NameError: name 'PolynomialFeatures' is not defined

# %%
X = df[['highway-mpg']]
Y = df['price']
lm.fit(X, Y)
lm.score(X, Y)
# Out:
# 0.4965911884339175

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# path of data 
path = 'https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DA0101EN/automobileEDA.csv'
df = pd.read_csv(path)
df.head()
# Out:
#    symboling  normalized-losses         make aspiration num-of-doors  \
# 0          3                122  alfa-romero        std          two
# 1          3                122  alfa-romero        std          two
# 2          1                122  alfa-romero        std          two
# 3          2                164         audi        std         four
# 4          2                164         audi        std         four
#
#     body-style drive-wheels engine-location  wheel-base    length  ...  \
# 0  convertible          rwd           front        88.6  0.811148  ...
# 1  convertible          rwd           front        88.6  0.811148  ...
# 2    hatchback          rwd           front        94.5  0.822681  ...
# 3        sedan          fwd           front        99.8  0.848630  ...
# 4        sedan          4wd           front        99.4  0.848630  ...
#
#    compression-ratio  horsepower  peak-rpm city-mpg highway-mpg    price  \
# ...

# %%
from sklearn.linear_model import LinearRegression
lm = LinearRegression()
lm
X = df[["highway-mpg"]]
Y = df[["price"]]

lm.fit(X,Y)
rSquared = lm.score(X,Y)

print("\n R Squared for the model:", rSquared)

Yhat = lm.predict(X)

print("\n Predicted Y hat (5 values) :\n", Yhat[0:5])

c = lm.intercept_
m = lm.coef_

print("\n Y intercept of the linear regression model: ", c)
print("\n Slope of the linear regression model: ", m)

predictedPrices = (m * df[["highway-mpg"]]) + c
predictedPrices
# Out:
#  R Squared for the model: 0.4965911884339175
#
#  Predicted Y hat (5 values) :
#  [[16236.50464347]
#  [16236.50464347]
#  [17058.23802179]
#  [13771.3045085 ]
#  [20345.17153508]]
#
#  Y intercept of the linear regression model:  [38423.30585816]
#
#  Slope of the linear regression model:  [[-821.73337832]]
#       highway-mpg
# 0    16236.504643
# 1    16236.504643
# 2    17058.238022
# 3    13771.304508
# 4    20345.171535
# 5    17879.971400
# 6    17879.971400
# 7    17879.971400
# 8    21988.638292
# 9    14593.037887
# 10   14593.037887
# 11   15414.771265
# 12   15414.771265
# 13   17879.971400
# 14   20345.171535
# 15   20345.171535
# 16   21988.638292
# 17   -5128.563193
# 18    3088.770590
# 19    3088.770590
# 20    4732.237347
# 21    7197.437482
# 22   13771.304508
# 23    7197.437482
# 24    7197.437482
# 25    7197.437482
# 26   13771.304508
# 27   13771.304508
# 28   18701.704778
# 29   -5950.296571
# ..            ...
# 171  12127.837752
# 172  12127.837752
# ...

# %%
LR = LinearRegression()

LR.fit(X, y)

yhat = LR.predict(X)
yhat.size()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-260-18298c2d63ca> in <module>
#       4
#       5 yhat = LR.predict(X)
# ----> 6 yhat.size()
#
# TypeError: 'int' object is not callable

# %%
Z = df[['horsepower', 'curb-weight', 'engine-size', 'highway-mpg']]

# %%
 cross_val_score(lre, x_data, y_data, cv=2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-264-670fba22b7ea> in <module>
# ----> 1 cross_val_score(lre, x_data, y_data, cv=2)
#
# NameError: name 'cross_val_score' is not defined

# %%
# Python Program to create a data type object 
import numpy as np 

df.head()

npObj = np.array(df) 

print("dtype of the numpy object is:", npObj.dtype)
# Out:
# dtype of the numpy object is: object

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler,PolynomialFeatures
# %matplotlib inline

file_name='https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DA0101EN/coursera/project/kc_house_data_NaN.csv'
df=pd.read_csv(file_name)

df.head()
# Out:
#    Unnamed: 0          id             date     price  bedrooms  bathrooms  \
# 0           0  7129300520  20141013T000000  221900.0       3.0       1.00
# 1           1  6414100192  20141209T000000  538000.0       3.0       2.25
# 2           2  5631500400  20150225T000000  180000.0       2.0       1.00
# 3           3  2487200875  20141209T000000  604000.0       4.0       3.00
# 4           4  1954400510  20150218T000000  510000.0       3.0       2.00
#
#    sqft_living  sqft_lot  floors  waterfront  ...  grade  sqft_above  \
# 0         1180      5650     1.0           0  ...      7        1180
# 1         2570      7242     2.0           0  ...      7        2170
# 2          770     10000     1.0           0  ...      6         770
# 3         1960      5000     1.0           0  ...      7        1050
# 4         1680      8080     1.0           0  ...      8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
for column in df.columns.values.tolist():
    print(column)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c74aeecb2e07> in <module>
# ----> 1 for column in df.columns.values.tolist():
#       2     print(column)
#       3
#
# NameError: name 'df' is not defined

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler,PolynomialFeatures
# %matplotlib inline

file_name='https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DA0101EN/coursera/project/kc_house_data_NaN.csv'
df=pd.read_csv(file_name)

df.head()

df.drop(['Unnamed: 0', 'id'], axis=1, inplace=True)

# %%
df.describe()
# Out:
#               price      bedrooms     bathrooms   sqft_living      sqft_lot  \
# count  2.161300e+04  21600.000000  21603.000000  21613.000000  2.161300e+04
# mean   5.400881e+05      3.372870      2.115736   2079.899736  1.510697e+04
# std    3.671272e+05      0.926657      0.768996    918.440897  4.142051e+04
# min    7.500000e+04      1.000000      0.500000    290.000000  5.200000e+02
# 25%    3.219500e+05      3.000000      1.750000   1427.000000  5.040000e+03
# 50%    4.500000e+05      3.000000      2.250000   1910.000000  7.618000e+03
# 75%    6.450000e+05      4.000000      2.500000   2550.000000  1.068800e+04
# max    7.700000e+06     33.000000      8.000000  13540.000000  1.651359e+06
#
#              floors    waterfront          view     condition         grade  \
# count  21613.000000  21613.000000  21613.000000  21613.000000  21613.000000
# mean       1.494309      0.007542      0.234303      3.409430      7.656873
# ...

# %%
#copying all the column names in a data frame to a list
df.columns.values.tolist()
# Out:
# ['date',
#  'price',
#  'bedrooms',
#  'bathrooms',
#  'sqft_living',
#  'sqft_lot',
#  'floors',
#  'waterfront',
#  'view',
#  'condition',
#  'grade',
#  'sqft_above',
#  'sqft_basement',
#  'yr_built',
#  'yr_renovated',
#  'zipcode',
#  'lat',
#  'long',
#  'sqft_living15',
#  'sqft_lot15']

# %%
floorsList = df['floors']
floorsList.value_counts().to_frame()
# Out:
#      floors
# 1.0   10680
# 2.0    8241
# 1.5    1910
# 3.0     613
# 2.5     161
# 3.5       8

# %%
ax = sns.boxplot(x=df['waterfront'], y=df['price'])

# %%
ax = sns.regplot(x=df['sqft_above'], y=df['price'])

# %%
# import LinearRegression module from scikit learn
from sklearn.linear_model import LinearRegression

# instantiate a linear regression model
lm = LinearRegression()

# select X as a predictor variable & Y as a target variable to construct a simple linear regression model
X = df[["sqft_living"]]
Y = df[["price"]]

# create a linear regression model (Y = MX + C)
lm.fit(X,Y)

# retrieve the coefficient/slope, M from linear regression model, Y = MX + C
M = lm.coef_
print("M, slope of the linear model based on square feet of living area is: ", M)

# retrieve the Y intercept, C from linear regression model, Y = MX + C
C = lm.intercept_
print("C, intercept of the linear model with Y-Axis based on squarefeet of living area is: ", C)

# the linear regression model (equation is)
print("Linear regression model (equation is), {Y = ",M,"X + ",C,"}")

# calculate R square
rSquared = lm.score(X,Y)
print("R Squared (variance) of price based on square feet of living area is: ", rSquared)

#finally visualize the simple linear regression model to get a feel for the regression line with positive slope 
ax = sns.regplot(x=df['sqft_living'], y=df['price'])
# Out:
# M, slope of the linear model based on square feet of living area is:  [[280.6235679]]
# C, intercept of the linear model with Y-Axis based on squarefeet of living area is:  [-43580.74309447]
# Linear regression model (equation is), {Y =  [[280.6235679]] X +  [-43580.74309447] }
# R Squared (variance) of price based on square feet of living area is:  0.49285321790379316

# %%
# Import LinearRegression module from scikit learn
from sklearn.linear_model import LinearRegression

# Instantiate a linear regression model
lm = LinearRegression()

# Check for missing data (NaN) in the dataframe; got an error when trying to invoke the lm.fit() indicating there may be nulls
missing_data = df.isnull()

for column in missing_data.columns.values.tolist():
    print(column)
    print (missing_data[column].value_counts())
    print("")    

# Found missing data for bedrooms (13) & bathrooms (10). Let's replace the missing values with average values 
# Average number of bedrooms 
avg_num_bedrooms = df["bedrooms"].astype("float").mean(axis=0)
print("\n Average Number of Bedrooms:", avg_num_bedrooms)

avg_num_bathrooms = df["bathrooms"].astype("float").mean(axis=0)
print("\n Average Number of Bathrooms:", avg_num_bathrooms)

# Let's replace (inplace) the missing data with average values for bedrooms & bathrooms 
df["bedrooms"].replace(np.nan, avg_num_bedrooms, inplace=True)
df["bathrooms"].replace(np.nan, avg_num_bathrooms, inplace=True)

# For Multiple Linear Regression, Yhat = a + b1X1 + b2X2 + b3X3... where Xi is a predictor variable
Z=df[["floors", 
      "waterfront", 
      "lat", 
      "bedrooms", 
      "sqft_basement", 
      "view", 
      "bathrooms", 
      "sqft_living15", 
      "sqft_above", 
      "grade", 
      "sqft_living"]]
   
# Fit the linear model using the above-mentioned 11 variables.
lm.fit(Z, df['price'])

y_intercept = lm.intercept_
x_coefficients = lm.coef_

# The Y intercept is
print("\n The intercept of the multiple linear regression model is: ", y_intercept )

# The X coefficients are 
print("\n The coefficients of the multiple linear regression model are: ", x_coefficients)

print("\n The Equation is \n Y =  -32374599.85823347 -3.02719103e+04(X1) + 6.02395424e+05(X2)  + 6.72699237e+05(X3) + \
-2.59999063e+04(X4) -7.45834891e+14(X5) + 6.70914473e+04(X6)  - 3.27155442e+03(X7) + \
4.57011445e+00(X8) -7.45834891e+14(X9) + 8.20190629e+04(X10) + 7.45834891e+14(X11)")

rSquared = lm.score(Z,df['price'])
print("R Squared (variance) of price based the 11 variables: ", rSquared)

#finally visualize the simple linear regression model to get a feel for the regression line with positive slope 
#ax = sns.regplot(x=Z, y=df['price'])
# Out:
# date
# False    21613
# Name: date, dtype: int64
#
# price
# False    21613
# Name: price, dtype: int64
#
# bedrooms
# False    21600
# True        13
# Name: bedrooms, dtype: int64
#
# bathrooms
# False    21603
# True        10
# Name: bathrooms, dtype: int64
#
# sqft_living
# False    21613
# Name: sqft_living, dtype: int64
#
# sqft_lot
# False    21613
# Name: sqft_lot, dtype: int64
#
# floors
# False    21613
# Name: floors, dtype: int64
#
# waterfront
# False    21613
# Name: waterfront, dtype: int64
#
# view
# False    21613
# Name: view, dtype: int64
#
# condition
# False    21613
# Name: condition, dtype: int64
#
# grade
# False    21613
# Name: grade, dtype: int64
#
# sqft_above
# False    21613
# Name: sqft_above, dtype: int64
#
# sqft_basement
# False    21613
# Name: sqft_basement, dtype: int64
#
# yr_built
# False    21613
# Name: yr_built, dtype: int64
#
# yr_renovated
# False    21613
# Name: yr_renovated, dtype: int64
#
# zipcode
# False    21613
# ...

# %%
df.corr()
# Out:
#                   price  bedrooms  bathrooms  sqft_living  sqft_lot    floors  \
# price          1.000000  0.308797   0.525738     0.702035  0.089661  0.256794
# bedrooms       0.308797  1.000000   0.514194     0.578077  0.032307  0.178022
# bathrooms      0.525738  0.514194   1.000000     0.755371  0.087929  0.502132
# sqft_living    0.702035  0.578077   0.755371     1.000000  0.172826  0.353949
# sqft_lot       0.089661  0.032307   0.087929     0.172826  1.000000 -0.005201
# floors         0.256794  0.178022   0.502132     0.353949 -0.005201  1.000000
# waterfront     0.266369 -0.006800   0.063744     0.103818  0.021604  0.023698
# view           0.397293  0.080058   0.188341     0.284611  0.074710  0.029444
# condition      0.036362  0.026690  -0.126197    -0.058753 -0.008958 -0.263768
# grade          0.667434  0.356589   0.664676     0.762704  0.113621  0.458183
# sqft_above     0.605567  0.479286   0.686309     0.876597  0.183512  0.523885
# ...

# %%
Yhat = lm.predict(Z)

width = 12
height = 10
plt.figure(figsize=(width, height))


ax1 = sns.distplot(df['price'], hist=False, color="r", label="Actual Value")
sns.distplot(Yhat, hist=False, color="b", label="Fitted Values" , ax=ax1)


plt.title('Actual vs Fitted Values for Home Prices')
plt.xlabel('Home Price (in dollars)')
plt.ylabel('Proportion of Homes in the sample')

plt.show()
plt.close()

# %%
# Data Pipelines are used to simplify the steps of processing the data. 
# Data Pipelines implement utilities to build a composite estimator, as a sequence of transforms and estimators.
# Here in this example we create a pipeline & a StandardScaler as a step in our pipeline.
# Import r2_score(), regression score function from sci-kit learn that'll be used to calc coeff of determination

from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score

# Create a pipeline object that scales the data performs a polynomial transform and fits a linear regression model
#   first create a list of tuples (scale, type of transform(polynomial), model) & call it 'Input', to feed the pipeline; 
#   these include, how to scale, features & the name of the model (or estimator) & corresponding constructor (linear regression)
Input=[('scale',StandardScaler()), ('polynomial', PolynomialFeatures(include_bias=False)), ('model',LinearRegression())]

# Direct the list (Input) as an argument to the pipeline constructor 
pipe=Pipeline(Input)
pipe

# Create a data frame (ensure has values) that contains all the 11 predictor variables to feed to the data pipe
Z=df[["floors", 
      "waterfront", 
      "lat", 
      "bedrooms", 
      "sqft_basement", 
      "view", 
      "bathrooms", 
      "sqft_living15", 
      "sqft_above", 
      "grade", 
      "sqft_living"]]
  
# Normalize the data, perform a transform and fit the model simultaneously (remember, using pipeline simplifies the code)
pipe.fit(Z,df['price'])

# Using the pipe predict all the 11 coefficients
ypipe=pipe.predict(Z)
ypipe[0:11]


# Calculate the new value of R squared using the pipe.score() method
rSquaredNew = pipe.score(Z,df['price'])
print("\n The old R Squared (variance) of price based the 11 variables: ", rSquared)
print("\n The new R Squared (variance) of price based the 11 variables: ", rSquaredNew)
# Out:
#  The old R Squared (variance) of price based the 11 variables:  0.657679183672129
#
#  The new R Squared (variance) of price based the 11 variables:  0.7513408553851407

# %% [markdown]
# ## Sort a list of key value pairs and produce the top three most occuring keys

# %%
# Create a list of lists (Actor, Movie) pairs
givenList = [['Leonardo DiCaprio','The Revenant'],
             ['Christian Bale','Vice'], 
             ['Morgan Freeman','Shawshank Redemption'],
             ['Leonardo DiCaprio','The Great Gatsby'],
             ['Ashley Judd','High Crimes'],
             ['Christian Bale','American Psycho'],
             ['Ashley Judd','Kiss the Girls'],
             ['Morgan Freeman','The Dark Knight'],
             ['Ashley Judd','Double Jeopardy'],
             ['Ashley Judd','Normal Life'],
             ['Christian Bale','The Dark Knight'],
             ['Samuel L. Jackson','Pulp Fiction']]

# The plan is to get all the actors in the given list, find unique actors, count occurances,
#     sort by occurances(2nd key), pick the top 3 & finally sort & display. 
#     the author of this program (M.BEHARA) believes that code should be readable.

# Retrieve all the actors from the givenList & sort the list
actorList = []
for actor, movie in givenList:
    actorList.append(actor)
    actorList.sort()
#print("ALL ACTORS    : ",actorList, "\n")


# Scan for unique actor names in the actors list (to count no. of appearances)     
i = 0 
uniqueActors = []
uniqueActors.append(actorList[0])
for actor in actorList: 
    if actor != uniqueActors[i]:
        uniqueActors.append(actor)
        i += 1
#print("UNIQUE ACTORS : ",uniqueActors, "\n")


# Create a function to return 2nd element of a key value pair (list)
def sortSecond(val): 
    return val[1]  

topActors=[]
for actor in uniqueActors:
    topActors.append([actor, actorList.count(actor)])
    topActors.sort(key = sortSecond, reverse = True)

#print("TOP ACTORS    : ", topActors, "\n")

# Print top 3 actors based on counts     
sortedTopActors = []
for i in range(len(topActors)-1):
    sortedTopActors.append(topActors[i][0])
    #print(topActors[i][0])

# Again sort list alphabetically
sortedTopActors.sort()

# Finally Print the top actors list
for actor in sortedTopActors:
    print(actor)

#Reinitialize the 4 lists after each run of this program
sortedTopActors = []
topActors = []    
uniqueActors = []
actorList = []
# Out:
# Ashley Judd
# Christian Bale
# Leonardo DiCaprio
# Morgan Freeman

# %%
import sys

line = sys.stdin.readline()
print(line)

# %% [markdown]
# ## Pick a subset of projects for highest return on investment constrained by total budget

# %%
# Define a list of items where each item has 3 elements
givenList = [['Pac-man',90,400],
["Mortal Kombat",10,30],
["ijk",10,90],             
["Super Tetris",25,100],
["xyz", 150, 900],             
["Pump it Up",10,40],
["Street Fighter II",90,450],
["lmn",5,50],             
["abc",10,80],             
["Speed Racer",10,40]]

# Remove any games that cost more than 120 minutes
filteredList = []
i = 0
for game, cost, reward in givenList:
    if(cost <= 120):
        filteredList.append(givenList[i])
        i += 1
    else:
        i += 1

print("\nFiltered list  : ", filteredList)


# Define a Sort function that in turn utilizes a Lambda function to sort by highest rate of return (points/time)
def sortBy3rdElement(itemsList): 
    # Sort by reward potential; reverse = None|True(Sorts in Ascending|Descending order)
    #return(sorted(itemsList, key = lambda x: x[2], reverse = True))     
     return(sorted(itemsList, key = lambda x: x[2]/x[1], reverse = True))     

# Pass the the above list to the function to return a sorted list & store the list
sortedList = []
sortedList = sortBy3rdElement(filteredList)
print("\nSorted list 1 : ", sortedList)



# Get the first item of Sorted List & remove from sorted list (we only have to select items from remaining list)
selectedList = [sortedList[0][0]]
usedBudget = int(sortedList[0][1])
sortedList.remove(sortedList[0])


for game, cost, reward in sortedList:
    if((cost + usedBudget) > 120):
        sortedList.remove(sortedList[0])

print("\nSorted list 2 : ", sortedList)
        
print("1. Used Budget: ", usedBudget)


prevCost = 0
for game, cost, reward in sortedList:
    print("1. Current game : ", game," cost : ", cost, " reward : ", reward)
    if(usedBudget == 120):
        print("Done!!!")
    else:
        if((usedBudget) < 120):
            if(cost < prevCost):
                if ((usedBudget + cost) <= 120):
                    usedBudget += cost
                    print("Appending Game :", game)
                    selectedList.append(game)
                else:
                    usedBudget -= prevCost
                    selectedList.pop()
                    usedBudget += cost
                    print("Appending Game :", game)
                    selectedList.append(game)
                    print("2. Used Budget: ", usedBudget)
            else:
                prevCost = cost
                usedBudget += cost
                print("3. Used Budget: ", usedBudget)
                print("Appending Game :", game)
                selectedList.append(game)

if usedBudget > 120:
    selectedList.pop()
    
print(selectedList)
# Out:
# Filtered list  :  [['Pac-man', 90, 400], ['Mortal Kombat', 10, 30], ['ijk', 10, 90], ['Super Tetris', 25, 100], ['Pump it Up', 10, 40], ['Street Fighter II', 90, 450], ['lmn', 5, 50], ['abc', 10, 80], ['Speed Racer', 10, 40]]
#
# Sorted list 1 :  [['lmn', 5, 50], ['ijk', 10, 90], ['abc', 10, 80], ['Street Fighter II', 90, 450], ['Pac-man', 90, 400], ['Super Tetris', 25, 100], ['Pump it Up', 10, 40], ['Speed Racer', 10, 40], ['Mortal Kombat', 10, 30]]
#
# Sorted list 2 :  [['ijk', 10, 90], ['abc', 10, 80], ['Street Fighter II', 90, 450], ['Pac-man', 90, 400], ['Super Tetris', 25, 100], ['Pump it Up', 10, 40], ['Speed Racer', 10, 40], ['Mortal Kombat', 10, 30]]
# 1. Used Budget:  5
# 1. Current game :  ijk  cost :  10  reward :  90
# 3. Used Budget:  15
# Appending Game : ijk
# 1. Current game :  abc  cost :  10  reward :  80
# 3. Used Budget:  25
# Appending Game : abc
# 1. Current game :  Street Fighter II  cost :  90  reward :  450
# 3. Used Budget:  115
# ...

# %%
# Define a list of items where each item has 3 elements
givenList = [['Pac-man',90,400],
["Mortal Kombat",10,30],
["Super Tetris",25,100],
["Pump it Up",10,40],
["Street Fighter II",90,450],
["Speed Racer",10,40]]

# Remove any games that cost more than 120 minutes
filteredList = []
i = 0
for game, cost, reward in givenList:
    if(cost <= 120):
        filteredList.append(givenList[i])
        i += 1
    else:
        i += 1

# Define a Sort function that in turn utilizes a Lambda function to sort by highest rate of return (points/time)
def sortBy3rdElement(itemsList): 
    # Sort by reward potential; reverse = None|True(Sorts in Ascending|Descending order)
    #return(sorted(itemsList, key = lambda x: x[2], reverse = True))     
     return(sorted(itemsList, key = lambda x: x[2]/x[1], reverse = True))     

# Pass the the above list to the function to return a sorted list & store the list
sortedList = []
sortedList = sortBy3rdElement(filteredList)

# Get the first item of Sorted List & remove from sorted list (we only have to select items from remaining list)
selectedList = [sortedList[0][0]]
usedBudget = int(sortedList[0][1])
sortedList.remove(sortedList[0])

# Remove any other games that'll exceed the total time
for game, cost, reward in sortedList:
    if((cost + usedBudget) > 120):
        sortedList.remove(sortedList[0])

# Go through the remainder of sorted list to select rest of the games
prevCost = 0
for game, cost, reward in sortedList:
    if(usedBudget == 120):
        skip
    else:
        if((usedBudget) < 120):
            if(cost < prevCost):
                if ((usedBudget + cost) <= 120):
                    usedBudget += cost
                    selectedList.append(game)
                else:
                    usedBudget -= prevCost
                    selectedList.pop()
                    usedBudget += cost
                    selectedList.append(game)
            else:
                prevCost = cost
                usedBudget += cost
                selectedList.append(game)

# Pop the last game (fix this code)                
if usedBudget > 120:
    selectedList.pop()

# Sort the final list in alphabetical order
selectedList.sort()

# Display the final list
for game in selectedList:
    print(game)
# Out:
# Mortal Kombat
# Pump it Up
# Speed Racer
# Street Fighter II

# %% [markdown]
# ### How to detect the smallest subset of contiguous characters in a string of characters  (Coding Challenge)

# %%
parms[0] = '5'
parms[1] = '1 2 2 2 3 3 3 1'

rng = int(parms[0])
val = parms[1]

print(rng)
print(val)

lst = val.split(' ')
print(lst)


sto = []
#sto.append(lst[0])
#print("stored value : ", sto)

cnt = 1
for i in range(1, rng):
    print('list element at index ',i, ' is ', lst[i])
    if (lst[i] == lst[i-1]):
        if (len(sto) > 0):
            sto.pop()
        sto.append(lst[i])
        cnt += 1
    else:
        if (len(sto) > 0):
            sto.pop()
        sto.append(lst[i])
    

print("count = ", cnt)
print('selected', sto)
# Out:
# 5
# 1 2 2 2 3 3 3 1
# ['1', '2', '2', '2', '3', '3', '3', '1']
# list element at index  1  is  2
# list element at index  2  is  2
# list element at index  3  is  2
# list element at index  4  is  3
# count =  3
# selected ['3']

# %%
parms[0] = '16'
parms[1] = '1 2 2 2 4 4 4 4 4 5 5 5 5 3 3 1'

rng = int(parms[0])
val = parms[1]

print(rng)
print(val)

lst = val.split(' ')
print(lst)


sto = []
#print("stored value : ", sto)

for i in range(1, rng):
    print('list element at index ',i, ' is ', lst[i])
    if (lst[i] == lst[i-1]):
        sto.append(lst[i])
  
print('selected', sto)

#print ([ [s, sto.count(s)] for s in set(sto)])

sel = [ [s, sto.count(s)] for s in set(sto)]

print(sel)

print("\n The character in the smallest contiguous subset is ",sel[0][0]," occuring ", int(sel[0][1]) + 1, " times!")
# Out:
# 16
# 1 2 2 2 4 4 4 4 4 5 5 5 5 3 3 1
# ['1', '2', '2', '2', '4', '4', '4', '4', '4', '5', '5', '5', '5', '3', '3', '1']
# list element at index  1  is  2
# list element at index  2  is  2
# list element at index  3  is  2
# list element at index  4  is  4
# list element at index  5  is  4
# list element at index  6  is  4
# list element at index  7  is  4
# list element at index  8  is  4
# list element at index  9  is  5
# list element at index  10  is  5
# list element at index  11  is  5
# list element at index  12  is  5
# list element at index  13  is  3
# list element at index  14  is  3
# list element at index  15  is  1
# selected ['2', '2', '4', '4', '4', '4', '5', '5', '5', '3']
# [['3', 1], ['2', 2], ['4', 4], ['5', 3]]
#
#  The character in the smallest contiguous subset is  3  occuring  2  times!

# %% [markdown]
# ### Take file with numbers and translate the facevale in English words

# %%
# Hit compile and run to see a sample output.
# Read values from stdin, do NOT hard code input.

# THE FIRST ITEM REPRESENTS THE NUMBER OF ITEMS IN THE LIST
records = ['3', '9753', '864', '730']

# USE THE FOLLOWING CODE WHEN PASSING INPUT IN A CONSOLE
'''
import fileinput
import sys

records = []

for line in fileinput.input():
    records.append(line.strip())
    sys.stdout.write(line)
'''

def ret_units(n):
    rmd = int(n) % 10
    if (rmd == 1):
        return('One')
    elif (rmd == 2):
        return('Two')
    elif (rmd == 3):
        return('Three')
    elif (rmd == 4):
        return('Four')
    elif (rmd == 5):
        return('Five')
    elif (rmd == 6):
        return('Six')
    elif (rmd == 7):
        return('Seven')
    elif (rmd == 8):
        return('Eight')
    elif (rmd == 9):
        return('Nine')
    else:
        return(' ')


def ret_tens(n):
    rmd = int(n) % 100
    if(rmd >= 90):
        return('Ninety', 90)
    elif(rmd >= 80):
        return('Eighty', 80)
    elif(rmd >= 70):
        return('Seventy', 70)
    elif(rmd >= 60):
        return('Sixty', 60)
    elif(rmd >= 50):
        return('Fifty', 50)
    elif(rmd >= 40):
        return('Forty', 40)
    elif(rmd >= 30):
        return('Thirty', 30)
    elif(rmd >= 20):
        return('Twenty', 20)
    elif(rmd >= 10):
        return('Ten', 10)
    else:
        return (' ')


def ret_hundreds(n):
    rmd = int(n) % 1000
    if(rmd >= 900):
        return('Nine Hundred', 900)
    elif(rmd >= 808):
        return('Eight Hundred', 800)
    elif(rmd >= 700):
        return('Seven Hundred', 700)
    elif(rmd >= 600):
        return('Six Hundred', 600)
    elif(rmd >= 500):
        return('Five Hundred', 500)
    elif(rmd >= 400):
        return('Four Hundred', 400)
    elif(rmd >= 300):
        return('Three Hundred', 300)
    elif(rmd >= 200):
        return('Two Hundred', 200)
    elif(rmd >= 100):
        return('One Hundred', 100)
    else:
        return (' ')


def ret_thousands(n):
    qtt = int(n) // 1000
    if(qtt == 1):
        lst.append('One Thousand')
    elif(qtt == 2):
        lst.append('Two Thousand')
    elif(qtt == 3):
        lst.append('Three Thousand')
    elif(qtt == 4):
        lst.append('Four Thousand')
    elif(qtt == 5):
        lst.append('Five Thousand')
    elif(qtt == 6):
        lst.append('Six Thousand')
    elif(qtt == 7):
        lst.append('Seven Thousand')
    elif(qtt == 8):
        lst.append('Eight Thousand')
    elif(qtt == 9):
        lst.append('Nine Thousand')
    else:
        return (' ')

rng = int(records[0])
res = []

for i in range(1, rng+1):
    lst = []
    #print(records[i])
    x = int(records[i])
    if (x > 10000):
        print("The value is larger than maximum allowed (Ten Thousand")
    elif(x <= 0):
        print("The value is less than or equal to zero")
    else:
        if(x >= 1000):
            if (x % 1000 == 0):
                if (x / 1000 == 1):
                    lst.append("One Thousand")
                elif(x / 1000 == 2):
                    lst.append("Two Thousand")
                elif(x / 1000 == 3):
                    lst.append("Three Thousand")
                elif(x / 1000 == 4):
                    lst.append("Four Thousand")
                elif(x / 1000 == 5):
                    lst.append("Five Thousand")
                elif(x / 1000 == 6):
                    lst.append("Six Thousand")
                elif(x / 1000 == 7):
                    lst.append("Seven Thousand")
                elif(x / 1000 == 8):
                    lst.append("Eight Thousand")
                else:
                    lst.append("Nine Thousand")
                res.append(lst)
            else:
                ret_thousands(x)
                h, v = ret_hundreds(x-1000)
                lst.append(h)
                x = x - v
                t, v = ret_tens(x)
                lst.append(t)
                x = x - v
                u = ret_units(x)
                lst.append(u)
                res.append(lst)
        elif(x > 100):
            h, v = ret_hundreds(x-1000)
            lst.append(h)
            x = x - v
            t, v = ret_tens(x)
            lst.append(t)
            x = x - v
            u = ret_units(x)
            lst.append(u)
            res.append(lst)
        elif(x > 10):
            t, v = ret_tens(x)
            lst.append(t)
            x = x - v
            u = ret_units(x)
            lst.append(u)
            res.append(lst)
        else:
            u = ret_units(x)
            lst.append(u)
            res.append(lst)

#print(res)

for i in range(len(res)):
    #print(res[i])
    prt = ' '
    for j in range(len(res[i])):
        #print(res[i][j])
        prt = prt+' '+res[i][j]
    print(prt.strip())

#print(res)
# Out:
# Nine Thousand Seven Hundred Fifty Three
# Eight Hundred Sixty Four
# Seven Hundred Thirty

# %% [markdown]
# ### End of Murali's Notes (syntax reference)
